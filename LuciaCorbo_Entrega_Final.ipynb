# %% [markdown]
# # 📘 ENTREGA FINAL
#
# **Nombre del alumno: Lucía Corbo**

# %% [markdown]
# ## 🧩 Etapa 1: Recopilación y Preparación de Datos
# **Objetivo:** Demostrar habilidades en Python, familiaridad con el entorno de trabajo y conocimientos básicos sobre manipulación de datos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
import os
os.listdir("/content/drive/MyDrive/datasets")
# Out:
# Mounted at /content/drive
# ['ventas.csv',
#  'marketing.csv',
#  'clientes.csv',
#  'ventas.xlsx',
#  'marketing_nuevo.csv',
#  'clientes_nuevo.csv',
#  'ventas_nuevo.csv']

# %% [markdown]
# ### 1️⃣ Carga de datos

# %%
# TODO: Cargar los datasets como DataFrames usando pandas.
ruta_ventas = "/content/drive/MyDrive/datasets/ventas.csv"
ruta_clientes = "/content/drive/MyDrive/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/datasets/marketing.csv"
# Sugerencia: utilizar pd.read_csv() para cargar los archivos CSV.
ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_clientes)
marketing = pd.read_csv(ruta_marketing)
# Recordá verificar la ruta correcta y revisar las primeras filas con .head().
display(ventas.head(5))
display(clientes.head(5))
display(marketing.head(5))
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# ...

# %% [markdown]
# ### 2️⃣ Análisis exploratorio inicial

# %%
# TODO: Realizar un análisis exploratorio inicial de los DataFrames.
# Sugerencia: usar métodos como .info(), .describe(), .shape y .columns. dtypes.
# Esto te ayudará a entender la estructura y el contenido de los datos.
# Podés incluir comentarios sobre observaciones iniciales.

"""
#VENTAS
print("----- VENTAS -----")
print("\nShape:", ventas.shape)
print("\nColumnas:", ventas.columns.tolist())
print("\nTipos de datos:\n", ventas.dtypes)
print("\nNulos por columna:\n", ventas.isna().sum())
print("\nPrimeras 3 filas: ")
display(ventas.head(3))
print("\nColumnas con datos numericos: ")
display(ventas.describe(include='number'))
print("\n"+"-"*50+"\n")


#CLIENTES
print("----- CLIENTES -----")
print("\nShape:", clientes.shape)
print("\nColumnas:", clientes.columns.tolist())
print("\nTipos de datos:\n", clientes.dtypes)
print("\nNulos por columna:\n", clientes.isna().sum())
print("\nPrimeras 3 filas: ")
display(clientes.head(3))
print("\nColumnas con datos numericos: ")
display(clientes.describe(include='number'))
print("\n"+"-"*50+"\n")


#MARKETING
print("----- MARKETING -----")
print("\nShape:", marketing.shape)
print("\nColumnas:", marketing.columns.tolist())
print("\nTipos de datos:\n", marketing.dtypes)
print("\nNulos por columna:\n", marketing.isna().sum())
print("\nPrimeras 3 filas: ")
display(marketing.head(3))
print("\nColumnas con datos numericos: ")
display(marketing.describe(include='number'))
"""

#Deje el código anterior comentado porque si bien empece a resolverlo asi,
#prefiero dejarlo como una función

def analizar_dataframe(df, nombre="DataFrame"):
    print(f"----- {nombre.upper()} -----")
    print("\nShape:", df.shape)
    print("\nColumnas:", df.columns.tolist())
    print("\nTipos de datos:\n", df.dtypes)
    print("\nNulos por columna:\n", df.isna().sum())
    print("\nPrimeras 3 filas: ")
    display(df.head(3))
    print("\nColumnas con datos numericos: ")
    display(df.describe(include='number'))
    print("\n" + "-"*50 + "\n")

analizar_dataframe(ventas, "Ventas")
analizar_dataframe(clientes, "Clientes")
analizar_dataframe(marketing, "Marketing")
# Out:
# ----- VENTAS -----
#
# Shape: (3035, 6)
#
# Columnas: ['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta', 'categoria']
#
# Tipos de datos:
#  id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# Nulos por columna:
#  id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Primeras 3 filas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# Columnas con datos numericos:
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# ...

# %% [markdown]
# ### 3️⃣ Calidad de los datos

# %%
# TODO: Identificar valores nulos y duplicados en los conjuntos de datos.
# Sugerencia: usar .isna().sum() y .duplicated().sum().
# Documentar las observaciones con print() o comentarios.

def control_calidad_datos(df, nombre_df, columna_id):
    print(f"\n----- {nombre_df} -----")
    print("\nNulos por columna:")
    display(df.isna().sum().to_frame("nulos"))

    duplicadas = df.duplicated().sum()
    print(f"\nFilas totales duplicadas: {duplicadas}")

    if columna_id and columna_id in df.columns:
        duplicados_col = df[columna_id].duplicated().sum()
        print(f"\nDuplicados en la columna '{columna_id}': {duplicados_col}")

"""
Arme una función para revisar la calidad de los 3 Dataframes para no repetir
siempre lo mismo de: ver los nulos, contar filas duplicadas y chequear
duplicados en una columna del id.
Paso el DataFrame y el nombre de la columna del id como parámetros.
"""
control_calidad_datos(ventas, "VENTAS", columna_id="id_venta")
control_calidad_datos(clientes, "CLIENTES", columna_id="id_cliente")
control_calidad_datos(marketing, "MARKETING", columna_id="id_campanha")
# Out:
# ----- VENTAS -----
#
# Nulos por columna:
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# Filas totales duplicadas: 35
#
# Duplicados en la columna 'id_venta': 35
#
# ----- CLIENTES -----
#
# Nulos por columna:
#             nulos
# id_cliente      0
# nombre          0
# edad            0
# ciudad          0
# ingresos        0
# Filas totales duplicadas: 0
#
# Duplicados en la columna 'id_cliente': 0
#
# ----- MARKETING -----
#
# Nulos por columna:
#               nulos
# id_campanha       0
# producto          0
# canal             0
# costo             0
# fecha_inicio      0
# fecha_fin         0
# Filas totales duplicadas: 0
#
# Duplicados en la columna 'id_campanha': 0

# %% [markdown]
# ## 🧹 Etapa 2: Preprocesamiento y Limpieza de Datos
# **Objetivo:** Demostrar conocimiento de las técnicas de limpieza y transformación de datos.

# %% [markdown]
# ### 1️⃣ Limpieza de datos

# %%
# TODO: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados.
# Sugerencia: aplicar .drop_duplicates(), .str.strip(), .str.replace() según el caso.
# Documentar el proceso y los resultados.

# 1) Hago copias para no modificar Dataframes originales
ventas_clean = ventas.copy()
clientes_clean = clientes.copy()
marketing_clean = marketing.copy()

# 2) Saco filas repetidas
ventas_clean = ventas_clean.drop_duplicates()
clientes_clean = clientes_clean.drop_duplicates()
marketing_clean = marketing_clean.drop_duplicates()

# 3) NORMALIZAR
#Texto
def normalizar_texto(df):
    for col in df.select_dtypes(include="object").columns:
        df[col] = (
            df[col]
            .astype(str)
            .str.strip()
            #Los caracteres invisibles a 1 espacio
            .str.replace(r"[\u200b\t\r\n]", " ", regex=True)
            # Más de un espacios pasa a uno
            .str.replace(" +", " ", regex=True)
            .str.title()
        )
    return df

#Fechas
"""si en la columna esta 'fechas' (aunque tenga algo mas) lo pasa a datetime
como dd/mm/yyyy
"""

def normalizar_fechas(df):
    for col in df.columns:
        if "fecha" in col.lower():
            df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)
            df[col] = df[col].dt.strftime("%d/%m/%Y")
    return df

# Precio
"""Normalizo solo precio porque: En Ventas cantidad es float, precio es object.
En Clientes edad es int e ingresos es float. En Marketing costo es float.
El precio object es el único a normalizar y pasar a float. Primero sacando $ y
despues cambiando "," por "" vacio por si hay miles separados con coma"""
def normalizar_precio(df):
    if "precio" in df.columns:
        df["precio"] = (
            df["precio"]
            .astype(str)
            .str.replace("$", "", regex=False)   # saca el $
            .str.replace(",", "", regex=False)   #cambia 1,000.00 a 1000.00
        )
        df["precio"] = pd.to_numeric(df["precio"], errors="coerce")
    return df


#TODO JUNTO
"""Como uso el bucle for hace que si por ejemplo no hay 'fecha' en alguno de
los Datasets no rompe porque solo no entra al bucle, por eso lo aplico a todos
Igualmente no se si es lo más conveniente en cuanto a optimización"""
def normalizar_todo(df):
    df = normalizar_texto(df)
    df = normalizar_fechas(df)
    df = normalizar_precio(df)
    return df

# 4) Guardar las normalizaciones en los ya limpios
ventas_normalizado   = normalizar_todo(ventas_clean)
clientes_normalizado = normalizar_todo(clientes_clean)
marketing_normalizado = normalizar_todo(marketing_clean)

# 5) Ver resultados

print("*"*25 +" ANTES "+"*"*25+"\n")
analizar_dataframe(ventas, "Ventas")
print("*"*25 +" DESPUES "+"*"*25+"\n")
analizar_dataframe(ventas_normalizado, "Ventas")
print("\n"+"-"*50+"\n")

print("*"*25 +" ANTES "+"*"*25+"\n")
analizar_dataframe(clientes, "Clientes")
print("*"*25 +" DESPUES "+"*"*25+"\n")
analizar_dataframe(clientes_normalizado, "Clientes")
print("\n"+"-"*50+"\n")

print("*"*25 +" ANTES "+"*"*25+"\n")
analizar_dataframe(marketing, "Marketing")
print("*"*25 +" DESPUES "+"*"*25+"\n")
analizar_dataframe(marketing_normalizado, "Marketing")
print("\n"+"-"*50+"\n")


# 6) Reporte (lo que está en la pre-entrega resulta para comparar con mis resultados)
def reporte(dfs, nombres):
    resumen = []
    for df, nombre in zip(dfs, nombres):
        filas = len(df)
        columnas = len(df.columns)
        nulos = df.isna().sum().sum()
        duplicados = df.duplicated().sum()

        resumen.append({
            "Dataset": nombre,
            "Filas": filas,
            "Columnas": columnas,
            "Nulos totales": nulos,
            "Duplicados": duplicados,
        })

    return pd.DataFrame(resumen)

print("*"*25 +" COMPARACIÓN "+"*"*25+"\n")
print(reporte(
    [ventas, clientes, marketing],
    ["VENTAS Original", "CLIENTES Original", "MARKETING Original"]
))

print(reporte(
    [ventas_clean, clientes_clean, marketing_clean],
    ["VENTAS Copia", "CLIENTES Copia", "MARKETING Copia"]
))
# Out:
# ************************* ANTES *************************
#
# ----- VENTAS -----
#
# Shape: (3035, 6)
#
# Columnas: ['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta', 'categoria']
#
# Tipos de datos:
#  id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# Nulos por columna:
#  id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Primeras 3 filas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# Columnas con datos numericos:
#           id_venta     cantidad
# ...

# %% [markdown]
# ### 2️⃣ Transformación de datos

# %%
# TODO: Aplicar filtros y transformaciones para crear una tabla de ventas
# que muestre solo los productos con alto rendimiento. calcular el percentil 80
# y filtrar los productos que superen ese umbral en ventas.
#quantile(0.8)
# Sugerencia: usar .query() o condiciones con operadores lógicos.

"""Estrategia pre-entrega clase:
Plan paso a paso:
Detectar la columna de producto
(tolerando distintos nombres: producto, id_producto, sku, articulo…).
Calcular ingreso por registro = precio * cantidad.
Agregar por producto para obtener métricas (ingreso_total, unidades,
precio_promedio, registros).
Calcular P80 con quantile(q=0.80).
Filtrar productos con ingreso_total >= P80.
Ordenar de mayor a menor."""


# 1) Detecta columna de producto
def detectar_columna_producto(df):
    posibles = ["producto", "id_producto", "sku", "articulo", "item"]
    cols_l = {c.lower(): c for c in df.columns}
    for c in posibles:
        if c in cols_l:
            return cols_l[c]
    raise ValueError("No se encontro columna de producto, (ni parecido).")

# 2) Hace precio * cant y agrega columna ingreso
def calcular_ingreso(df):
    #df = df.copy()
    df["precio"] = pd.to_numeric(df["precio"], errors="coerce")
    df["cantidad"] = pd.to_numeric(df["cantidad"], errors="coerce")
    df["ingreso"] = df["precio"] * df["cantidad"]
    return df

# 3) Metricas por producto
def resumen_por_producto(df, col_producto):
    return (
        df.groupby(col_producto, dropna=False)
          .agg(ingreso_total=("ingreso", "sum"), #son los ingresos totales del prod
               unidades=("cantidad", "sum"), #todas las cant vendidas
               precio_promedio=("precio", "mean"),
               registros=("ingreso", "size")) #cuantas entradas o filas hay del prod
          .reset_index()
    )

# 4) Filtrar alto rendimiento
def filtrar_alto_rendimiento(tabla, percentil=0.80):
    p80 = tabla["ingreso_total"].quantile(percentil)
    top = (
        tabla.loc[tabla["ingreso_total"] >= p80]
             .sort_values("ingreso_total", ascending=False)
             .reset_index(drop=True)
    )
    return p80, top

# 5) TODO
def tabla_alto_rendimiento(df, percentil=0.80):
    col_producto = detectar_columna_producto(df)
    df_ingreso = calcular_ingreso(df)
    tabla = resumen_por_producto(df_ingreso, col_producto)
    p80, top = filtrar_alto_rendimiento(tabla, percentil)
    return col_producto, p80, tabla, top

# 6) ver resultados
prod_col, p80_ingreso, ventas_resumen, ventas_top = tabla_alto_rendimiento(ventas_normalizado)

print(f"Columna de producto detectada: {prod_col}")
print(f"Umbral (percentil 80) de ingreso_total: {float(p80_ingreso):,.2f}")
print("✅ Productos de ALTO RENDIMIENTO (top 20% por ingreso):\n")
print("*"*25 +" REULTADO "+"*"*25+"\n")
display(ventas_top.head(20))
# Out:
# Columna de producto detectada: producto
# Umbral (percentil 80) de ingreso_total: 52,518.85
# ✅ Productos de ALTO RENDIMIENTO (top 20% por ingreso):
#
# ************************* REULTADO *************************
#             producto  ingreso_total  unidades  precio_promedio  registros
# 0    Lámpara De Mesa       82276.38    1112.0        72.720625        176
# 1        Auriculares       74175.58     958.0        76.302727        143
# 2         Microondas       72562.89     912.0        79.176000        135
# 3           Cafetera       59607.31     765.0        79.046581        117
# 4  Cuadro Decorativo       54297.60     726.0        74.578000        100
# 5         Smartphone       54132.44     665.0        81.398416        101

# %% [markdown]
# 2️⃣.2)  Prueba pasar tabla a gráfico con Matplotlib

# %%
top20 = ventas_top.head(20) #aunque se q son solo 6 asi queda como la tabla

plt.figure(figsize=(8,5))
sns.barplot(
    data=top20,
    x="ingreso_total",
    y="producto",
    hue="producto",
    dodge=False,
    legend=False,
    palette="viridis_r"
)

plt.title("Productos con más rendimiento", fontsize=12)
plt.xlabel("Ingreso total $")
plt.ylabel("Producto")
plt.tight_layout()
plt.show()

# %% [markdown]
# 2️⃣.3)  Prueba tabla con estilo (con mucha IA)

# %%
emoji_map = {
    "Lámpara": "💡",
    "Auriculares": "🎧",
    "Microondas": "🍲",
    "Cafetera": "☕",
    "Cuadro": "🖼️",
    "Smartphone": "📱"
}

rename_map = {
    "producto": "🌸 PRODUCTO 🌸",
    "ingreso_total": "💖 INGRESO TOTAL 💖",
    "unidades": "🎀 UNIDADES 🎀",
    "precio_promedio": "💲 PRECIO PROMEDIO 💲",
    "registros": "📔 REGISTRO 📔"
}

tabla_emojis = ventas_top.head(6).copy()
tabla_emojis = tabla_emojis.rename(columns=rename_map)

tabla_emojis["🌸 PRODUCTO 🌸"] = tabla_emojis["🌸 PRODUCTO 🌸"].apply(
    lambda x: f"{x} {next((emoji for key, emoji in emoji_map.items() if key.lower() in x.lower()), '')}"
)

tabla_emojis.index = [f"✨{i}✨" for i in range(1, len(tabla_emojis) + 1)]

tabla_girly = (
    tabla_emojis
        .style
        .format({
            "💖 INGRESO TOTAL 💖": "{:,.2f}",
            "💲 PRECIO PROMEDIO 💲": "{:,.2f}",
            "🎀 UNIDADES 🎀": "{:.0f}",
            "📔 REGISTRO 📔": "{:,.0f}"
        })
        .bar(subset=["💖 INGRESO TOTAL 💖"], color="#8ace91")
        .bar(subset=["🎀 UNIDADES 🎀"], color="#ce93d8")
        .set_table_styles(
            [
                {"selector": "thead th",
                 "props": [("background-color", "#f8bbd0"),
                           ("color", "black"),
                           ("font-weight", "bold"),
                           ("text-align", "center"),
                           ("border", "3px solid white"),
                           ("padding", "8px")]},
                {"selector": "td",
                 "props": [("border", "2px solid #f8bbd0"),
                           ("text-align", "center"),
                           ("padding", "6px")]}
            ]
        )
        .set_properties(subset=["💖 INGRESO TOTAL 💖"], **{"min-width": "240px", "color": "black"})
        .set_properties(subset=["🎀 UNIDADES 🎀"], **{"min-width": "240px", "color": "black"})
  )

display(tabla_girly)
# Out:
# <style type="text/css">
# #T_270fb thead th {
#   background-color: #f8bbd0;
#   color: black;
#   font-weight: bold;
#   text-align: center;
#   border: 3px solid white;
#   padding: 8px;
# }
# #T_270fb td {
#   border: 2px solid #f8bbd0;
#   text-align: center;
#   padding: 6px;
# }
# #T_270fb_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #8ace91 100.0%, transparent 100.0%);
#   min-width: 240px;
#   color: black;
# }
# #T_270fb_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #ce93d8 100.0%, transparent 100.0%);
#   min-width: 240px;
#   color: black;
# }
# #T_270fb_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #8ace91 90.2%, transparent 90.2%);
#   min-width: 240px;
#   color: black;
# }
# #T_270fb_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #ce93d8 86.2%, transparent 86.2%);
#   min-width: 240px;
#   color: black;
# }
# #T_270fb_row2_col1 {
#   width: 10em;
# ...

# %% [markdown]
# ### 3️⃣ Agregación

# %%
# TODO: Resumir las ventas por categoría de producto y analizar los ingresos generados.
# Sugerencia: usar .groupby() y .agg() para generar métricas como suma y promedio.

"""Estrategia pre-entrega clase:
Plan paso a paso:
Detectar la columna de categoría.
Asegurar columna ingreso (si no existe, crearla).
groupby(categoría).agg(...) para obtener métricas.
Ordenar por ingreso_total.
Calcular ticket_promedio_por_venta
"""

# 1) Encontrar columna de categoría
def encontrar_columna_categoria(df):
    posibles = ["categoria", "categoría", "rubro", "segmento", "family"]
    m = {c.lower(): c for c in df.columns}
    for c in posibles:
        if c in m:
            return m[c]
    raise ValueError("No se encontró columna de categoría (ni parecido)")

# 2) Columna ingreso si no existe se crea
def asegurar_ingreso(df):
    #df = df.copy()
    if "ingreso" not in df.columns:
        df["precio"] = pd.to_numeric(df["precio"], errors="coerce")
        df["cantidad"] = pd.to_numeric(df["cantidad"], errors="coerce")
        df["ingreso"] = df["precio"] * df["cantidad"]
    return df


# 3) Resumen por categoría y ticket promedio
def resumen_por_categoria(df):
    cat_col = encontrar_columna_categoria(df)
    df_con_ingreso = asegurar_ingreso(df)

    tabla = (
        df_con_ingreso.groupby(cat_col, dropna=False)
           .agg(
               ingreso_total=("ingreso", "sum"),
               ingreso_promedio=("ingreso", "mean"),
               ingreso_mediana=("ingreso", "median"),
               unidades=("cantidad", "sum"),
               ventas=("ingreso", "size"),
               precio_promedio=("precio", "mean")
           )
           .reset_index()
    )

    # Ticket promedio por venta
    tabla["ticket_promedio_por_venta"] = (
        tabla["ingreso_total"] / tabla["ventas"].replace(0, pd.NA)
    )

    #Con sort ordena desde mayor
    tabla = tabla.sort_values("ingreso_total", ascending=False, na_position="last")
    return cat_col, tabla

# 4) Aplicar a ventas_normalizado y ver resultados
cat_col, resumen_cat = resumen_por_categoria(ventas_normalizado)

print(f"Columna de categoría detectada: {cat_col}")
print("Resumen por categoría:")
display(resumen_cat.head(10))
# Out:
# Columna de categoría detectada: categoria
# Resumen por categoría:
#            categoria  ingreso_total  ingreso_promedio  ingreso_mediana  \
# 1  Electrodomésticos      505299.63         505.29963          418.215
# 2        Electrónica      482577.80         483.54489          419.580
# 0         Decoración      479216.09         479.21609          412.005
#
#    unidades  ventas  precio_promedio  ticket_promedio_por_venta
# 1    6592.0    1000         76.52096                 505.299630
# 2    6413.0     999         75.25492                 483.060861
# 0    6490.0    1001         74.09800                 478.737353

# %% [markdown]
# ### 🌸 Guardar nuevos datos como csv

# %%
#Nuevos nombres para no sobrescribir
ruta_ventas_nuevo = "/content/drive/MyDrive/datasets/ventas_nuevo.csv"
ruta_clientes_nuevo = "/content/drive/MyDrive/datasets/clientes_nuevo.csv"
ruta_marketing_nuevo = "/content/drive/MyDrive/datasets/marketing_nuevo.csv"

# dataFrames normalizados en nuevas rutas
ventas_normalizado.to_csv(ruta_ventas_nuevo, index=True)
clientes_normalizado.to_csv(ruta_clientes_nuevo, index=True)
marketing_normalizado.to_csv(ruta_marketing_nuevo, index=True)

# %% [markdown]
# ### 4️⃣ Integración de datos

# %%
# TODO: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.
# Sugerencia: usar pd.merge() especificando la clave común entre ambos DataFrames.
# Documentar cualquier observación relevante sobre la combinación de datos.

# Como en case:

# 1) Agrupo ventas_clean por producto y calculo ingreso total (precio * cantidad)
df_ventas_x_producto = ventas_clean.groupby('producto').agg(
    precio_por_cantidad=('precio', lambda x: (x * ventas_clean.loc[x.index, 'cantidad']).sum())
)

# Ordeno por producto
df_ventas_x_producto = df_ventas_x_producto.sort_values(by='producto', ascending=True)

display(df_ventas_x_producto)


# 2) Agrupo marketing_clean por producto y sumo el costo de campañas
df_marketing_x_producto = marketing_clean.groupby('producto')['costo'].sum().reset_index()

# Agarro columnas y ordeno
df_marketing_x_producto = df_marketing_x_producto[['producto', 'costo']]
df_marketing_x_producto = df_marketing_x_producto.sort_values(by='producto', ascending=True)

display(df_marketing_x_producto)


# 3) Merge entre ventas y marketing  por producto
merged_df = pd.merge(df_ventas_x_producto, df_marketing_x_producto, on='producto', how='inner')

display(merged_df)


# 4)  % del costo de marketing sobre el ingreso generado
merged_df['porcentaje_costo_sobre_ingreso'] = (merged_df['costo'] / merged_df['precio_por_cantidad']) * 100

display(merged_df)
# Out:
#                         precio_por_cantidad
# producto
# Adorno De Pared                    48093.49
# Alfombra                           44773.06
# Aspiradora                         50085.86
# Auriculares                        74175.58
# Batidora                           50979.20
# Cafetera                           59607.31
# Candelabro                         11128.80
# Consola De Videojuegos             46174.41
# Cortinas                           44865.03
# Cuadro Decorativo                  54297.60
# Cámara Digital                     45217.96
# Elementos De Cerámica              45411.09
# Espejo Decorativo                  46783.31
# Freidora Eléctrica                 50155.15
# Heladera                           25736.80
# Horno Eléctrico                    49913.90
# Jarrón Decorativo                  51130.88
# Laptop                             46179.48
# Lavadora                           48946.44
# Lámpara De Mesa                    82276.38
# ...

# %% [markdown]
# ## 📊 Etapa 3: Análisis de Datos
# **Objetivo:** Realizar análisis estadístico y exploratorio sobre los datos procesados.

# %% [markdown]
# ###1️⃣ Estadística Descriptiva

# %%
#Calcular medidas de tendencia central y# Calcular medidas de tendencia central
#y dispersion sobre las ventas

df = ventas_resumen.copy()

media = df['ingreso_total'].mean()
mediana = df['ingreso_total'].median()
rango = df['ingreso_total'].max() - df['ingreso_total'].min()
varianza = df['ingreso_total'].var(ddof=1)
desviacion = df['ingreso_total'].std(ddof=1)

print(f"Media de Ingreso Total: {media:,.2f}")
print(f"Mediana de Ingreso Total: {mediana:,.2f}")
print(f"Desviacion Estandar de Ingreso Total: {desviacion:,.2f}")
print(f"Rango de Ingreso Total: {rango:,.2f}")
print("Varianza:", varianza)
# Out:
# Media de Ingreso Total: 48,903.12
# Mediana de Ingreso Total: 48,140.24
# Desviacion Estandar de Ingreso Total: 13,265.56
# Rango de Ingreso Total: 71,147.58
# Varianza: 175975127.62545466

# %% [markdown]
# ###2️⃣ Análisis Exploratorio de Datos (EDA)

# %%
# Realizar un análisis exploratorio utilizando visualizaciones para
#identificar patrones y tendencias en las ventas.

import matplotlib.pyplot as plt
import seaborn as sns

rosa_pastel = "#ffb3c6"
rosa = "#ff66b3"
lila = "#c8a2ff"

df = ventas_resumen.copy()

plt.figure(figsize=(15,4))

# 1) Boxplot de ingreso_total
plt.subplot(1,3,1)
sns.boxplot(x=df['ingreso_total'], color=rosa_pastel)
plt.title("Boxplot de Ingreso Total")

# 2) Histograma
plt.subplot(1,3,2)
sns.histplot(df['ingreso_total'], bins=15, kde=True, color=rosa)
plt.title("Distribución de Ingreso Total")

# 3) Top 10 productos por ingreso total
top10 = df.sort_values("ingreso_total", ascending=False).head(10)
plt.subplot(1,3,3)
sns.barplot(data=top10, x="ingreso_total", y="producto", color=lila)
plt.title("Top 10 Ingresos por Producto")
plt.xlabel("Ingreso Total")
plt.ylabel("Producto")

plt.tight_layout()
plt.show()

# %% [markdown]
# ###3️⃣ Correlación

# %%
#Evaluar la relación entre diferentes variables (por ejemplo, precio y cantidad vendida) y
# mostrar los resultados en un gráfico.

import seaborn as sns
import matplotlib.pyplot as plt

rosa = "#ff66b3"
lila = "#c8a2ff"

df = ventas_resumen.copy()

# dispersión: precio vs unidades
plt.figure(figsize=(6,4))
sns.scatterplot(
    data=df,
    x='precio_promedio',
    y='unidades',
    color=rosa
)
plt.title("Relación: Precio Promedio vs Unidades Vendidas")
plt.xlabel("Precio Promedio")
plt.ylabel("Unidades")
plt.show()

# %%
# Coeficiente de correlación
corr_val = ventas_resumen[['precio_promedio','unidades']].corr().loc['precio_promedio','unidades']

print(f"Coeficiente de correlación (Pearson): {corr_val:.3f}")

if corr_val > 0.8:
    print("Interpretación: relación positiva fuerte.")
elif corr_val > 0.2:
    print("Interpretación: relación positiva débil a moderada.")
elif corr_val < -0.8:
    print("Interpretación: relación negativa fuerte.")
elif corr_val < -0.3:
    print("Interpretación: relación negativa débil a moderada.")
else:
    print("Interpretación: relación muy débil o nula.")
# Out:
# Coeficiente de correlación (Pearson): 0.217
# Interpretación: relación positiva débil a moderada.

# %%
# Prueba matriz de correlacion (con IA)
corr = df[['precio_promedio', 'unidades', 'ingreso_total']].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap=[rosa, lila], linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()

# %% [markdown]
# ###4️⃣ Consolidación de Datos

# %%
# Consolidar todos los análisis previos y preparar un conjunto de datos final
#que resuma los hallazgos clave para la presentación.

# hallazgos importantes del análisis:
# - ingreso_total por producto
# - unidades vendidas
# - precio promedio
# - productos de alto rendimiento (según P80)
# - resumen por categoría

df_final = ventas_resumen.copy()

# 2) SI pertenece al top 20% de alto rendimiento
df_final['alto_rendimiento'] = df_final['producto'].isin(ventas_top['producto'])
df_final['alto_rendimiento'] = df_final['alto_rendimiento'].map({True: "Sí", False: "No"})

# ordenar y mostrar lo que importa
df_final = df_final[['producto', 'ingreso_total', 'unidades', 'precio_promedio', 'alto_rendimiento']]
df_final = df_final.sort_values('ingreso_total', ascending=False).reset_index(drop=True)

display(df_final.head(20))

# Por catgortia

df_categoria = (
    ventas_normalizado
    .groupby('categoria')
    .agg(
        ingreso_total=('ingreso_total','sum'),
        unidades=('cantidad','sum'),
        precio_promedio=('precio','mean')
    )
    .sort_values('ingreso_total', ascending=False)
    .reset_index()
)
display(df_categoria)
# Out:
#                producto  ingreso_total  unidades  precio_promedio  \
# 0       Lámpara De Mesa       82276.38    1112.0        72.720625
# 1           Auriculares       74175.58     958.0        76.302727
# 2            Microondas       72562.89     912.0        79.176000
# 3              Cafetera       59607.31     765.0        79.046581
# 4     Cuadro Decorativo       54297.60     726.0        74.578000
# 5            Smartphone       54132.44     665.0        81.398416
# 6              Secadora       52115.45     696.0        73.338900
# 7     Jarrón Decorativo       51130.88     672.0        74.534000
# 8              Batidora       50979.20     672.0        77.537200
# 9     Rincón De Plantas       50456.45     691.0        74.823861
# 10   Freidora Eléctrica       50155.15     630.0        78.251300
# 11           Aspiradora       50085.86     651.0        77.447400
# 12      Horno Eléctrico       49913.90     633.0        75.688800
# ...

# %% [markdown]
# ## 📈 Etapa 4: Visualización de Datos
# **Objetivo:** Aprender a visualizar datos de manera efectiva utilizando diversas bibliotecas.

# %% [markdown]
# ###1️⃣ Visualización con Matplotlib

# %%
#Crear gráficos básicos (líneas, barras, dispersión) que representen las ventas
#con diferentes periodos de tiempo.

import matplotlib.pyplot as plt
import pandas as pd

df_prod = ventas_resumen.copy()
df_time = ventas_normalizado.copy()


df_time['fecha_venta'] = pd.to_datetime(df_time['fecha_venta'], dayfirst=True)

# Agrupar ingresos
df_diario = (
    df_time.groupby('fecha_venta')
           .agg(ingreso_total=('ingreso_total','sum'))
           .reset_index()
)

# Tendencia acumulada
df_diario['ingreso_acumulado'] = df_diario['ingreso_total'].cumsum()

rosa = "#ff66b3"
lila = "#c8a2ff"

# 1) Barras — Ingresos por Producto
plt.figure(figsize=(12,4))
df_sorted = df_prod.sort_values('ingreso_total', ascending=False)
plt.bar(df_sorted['producto'], df_sorted['ingreso_total'], color=rosa)
plt.title("Ingresos por Producto", fontsize=14)
plt.xlabel("Producto")
plt.ylabel("Ingreso Total")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# 2) GRafico Líneas — Tendencia Acumulada en el Tiempo
plt.figure(figsize=(12,4))
plt.plot(df_diario['fecha_venta'], df_diario['ingreso_acumulado'], color=lila, linewidth=2)
plt.title("Tendencia Acumulada de Ventas")
plt.xlabel("Fecha")
plt.ylabel("Ingreso Acumulado")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3) Grafico Líneas — Tendencia Real de Ingresos por Día
plt.figure(figsize=(12,4))
plt.plot(df_diario['fecha_venta'], df_diario['ingreso_total'], color=rosa, linewidth=2)
plt.title("Tendencia Real de Ingresos Diarios")
plt.xlabel("Fecha")
plt.ylabel("Ingreso Total Diario")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###2️⃣ Visualización Avanzada con Seaborn

# %%
# Desarrollar visualizaciones estadísticas avanzadas, utilizando paletas y
#estilos para mejorar la presentación.

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df_prod = ventas_resumen.copy()
df_cat = ventas_normalizado.copy()
df_cat['ingreso'] = df_cat['precio'] * df_cat['cantidad']

palette_productos = sns.color_palette(["#ff66b3", "#c8a2ff", "#ffcce6"],
                                      n_colors=len(df_prod))
palette_categorias = sns.color_palette(["#ffcce6", "#ff66b3", "#c8a2ff"],
                                       n_colors=df_cat['categoria'].nunique())

# Estilo general
sns.set_theme(style="whitegrid", font_scale=1.1)

# 1) Barras ordenadas — ingreso_total por producto
plt.figure(figsize=(12,6))
df_sorted = df_prod.sort_values("ingreso_total", ascending=False)
sns.barplot(
    data=df_sorted,
    x="producto",
    y="ingreso_total",
    hue="producto",
    palette=palette_productos,
    dodge=False
)
plt.title("Ingresos Totales por Producto (Seaborn)", weight="bold")
plt.xlabel("Producto")
plt.ylabel("Ingreso Total ($)")
plt.xticks(rotation=90)
plt.legend([],[], frameon=False)
plt.tight_layout()
plt.show()


# 2) Boxplot por categoría — ingreso por registro
plt.figure(figsize=(10,5))
sns.boxplot(
    data=df_cat,
    x="categoria",
    y="ingreso",
    hue="categoria",
    palette=palette_categorias,
    dodge=False
)
plt.title("Distribución del Ingreso por Categoría (Boxplot)", weight="bold")
plt.xlabel("Categoría")
plt.ylabel("Ingreso por Registro")
plt.xticks(rotation=45)
plt.legend([],[], frameon=False)
plt.tight_layout()
plt.show()

# 3) Prueba con Violinplot
plt.figure(figsize=(10,5))
sns.violinplot(
    data=df_cat,
    x="categoria",
    y="ingreso",
    hue="categoria",
    palette=palette_categorias,
    inner="quartile",
    legend=False
)
plt.title("Violinplot de Ingreso por Categoría", weight="bold")
plt.xlabel("Categoría")
plt.ylabel("Ingreso")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###3️⃣ Visualización Interactiva con Plotly

# %%
#Construir un dashboard interactivo que combine múltiples visualizaciones,
#permitiendo al usuario explorar los datos dinámicamente.

import plotly.graph_objects as go
import plotly.subplots as sp
import pandas as pd

df = ventas_normalizado.copy()
df['ingreso'] = df['precio'] * df['cantidad']
df['fecha_venta'] = pd.to_datetime(df['fecha_venta'], dayfirst=True)

# Agrupación semanal
df['semana'] = df['fecha_venta'].dt.to_period('W').apply(lambda r: r.start_time)
df_semana = df.groupby('semana')['ingreso'].sum().reset_index()

# Ingresos por categoría
df_cat = df.groupby('categoria')['ingreso'].sum().reset_index()

# dispersión: precio vs cantidad
df_scatter = df.copy()

rosa = "#ff66b3"
lila = "#c8a2ff"
rosa_pastel = "#ffcce6"

fig = sp.make_subplots(
    rows=2, cols=2,
    subplot_titles=[
        "📈 Tendencia Semanal de Ingresos",
        "📊 Ingreso por Categoría",
        "💬 Dispersión Precio vs Cantidad",
        ""
    ],
    specs=[[{"type": "scatter"}, {"type": "bar"}],
           [{"type": "scatter"}, {"type": "domain"}]]
)

# 1) Línea: Ingresos por semana
fig.add_trace(
    go.Scatter(
        x=df_semana['semana'],
        y=df_semana['ingreso'],
        mode='lines+markers',
        line=dict(color=rosa, width=3),
        marker=dict(color=rosa),
        name="Ingresos Semanales"
    ),
    row=1, col=1
)

# 2) Barras: Ingresos por categoría
fig.add_trace(
    go.Bar(
        x=df_cat['categoria'],
        y=df_cat['ingreso'],
        marker=dict(color=lila),
        name="Ingresos por Categoría"
    ),
    row=1, col=2
)

# 3) Scatter interactivo: Precio vs Cantidad
fig.add_trace(
    go.Scatter(
        x=df_scatter['precio'],
        y=df_scatter['cantidad'],
        mode='markers',
        marker=dict(size=10, color=rosa_pastel, line=dict(color=rosa, width=1)),
        name="Precio vs Cantidad"
    ),
    row=2, col=1
)

# Layout general
fig.update_layout(
    title="Dashboard Interactivo de Ventas (Plotly)",
    height=800,
    showlegend=False,
    template="plotly_white",
    font=dict(size=13, color="#333")
)

fig.update_xaxes(title_text="Fecha (Semana)", row=1, col=1)
fig.update_yaxes(title_text="Ingresos", row=1, col=1)

fig.update_xaxes(title_text="Categoría", row=1, col=2)
fig.update_yaxes(title_text="Ingresos", row=1, col=2)

fig.update_xaxes(title_text="Precio", row=2, col=1)
fig.update_yaxes(title_text="Cantidad Vendida", row=2, col=1)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-616496735.py in <cell line: 0>()
#       6 import pandas as pd
#       7
# ----> 8 df = ventas_normalizado.copy()
#       9 df['ingreso'] = df['precio'] * df['cantidad']
#      10 df['fecha_venta'] = pd.to_datetime(df['fecha_venta'], dayfirst=True)
#
# NameError: name 'ventas_normalizado' is not defined
